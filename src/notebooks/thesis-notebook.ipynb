# %% [markdown]
# # Investigating the impact of Social Media to the Quality of Life of its Users

# %% [markdown]
# This notebook includes all of the relevant functions that were used to calculate the results of the study. Run each individual cell to get the results described in the pdf ().
# The structure of the below cells follow the logic of the thesis analysis in Chapter 4 i.e:
# - Present the descriptive statistics
# - Show what distribution fits the data
# - Calculate means differences between the BSMAS groups and compare via t-tests and ANOVA
# - Develop and calculate the regression models.

# %% [markdown]
# ### Descriptive Statistics

# %%
from scripts.descriptive_statistics import DescriptiveStatistics, DescriptiveStatisticsPerGroup
# Calling the descriptive statistics functions
DescriptiveStatistics.DescriptiveStatistics()
DescriptiveStatisticsPerGroup.DescriptiveStatisticsPerGroup()

# %% [markdown]
# ### Parametric Tests (for testing the normality assumption and finding differences in the means of the BSMAS groups)

# %%
# Normality Tests before t-tests, ANOVA and regressions
import normality_tests
normality_tests.normality_tests()

# %%
#Finding differences in the means (t-tests)
import ttests
ttests.ttest()
ttests.ttest_with_separations()

# %% [markdown]
# ### Analysis of Variance

# %%
# ANOVA
from scripts.analysis_of_variance import anova_twoway_encoding, anova_dep_vars, anova_twoway_dep_vars
anova_dep_vars()
anova_twoway_dep_vars()
anova_twoway_encoding()

# %% [markdown]
# ### Regressions

# %%
# Assumption tests (also included in the OLS functions of statsmodels and scipy)
from scripts.regressions.assumption_tests import jarque_vera_test
jarque_vera_test.jarque_bera_test()

# %%
#Main regression models
from scripts.regressions.multivariate_linear_regressions import regression_models_main
regression_models_main.regression_models_main()

# %%
#Before the regression analysis to check whether the linear regression assumptions hold
from scripts.regressions.multivariate_linear_regressions import before_regressions_checks
before_regressions_checks()

# %%
#Bootstrapped linear regression
from scripts.regressions.multivariate_linear_regressions import bootstrapped_linear_regression_models
bootstrapped_linear_regression_models()

# %% [markdown]
# ### Plotcode

# %%
# Relevant plotcode
from scripts.plotcode.histogram import histograms
histograms()

# %% [markdown]
# ### Plotting residuals

# %% [markdown]
# ### Plotting Heatmaps

# %% [markdown]
# ### Plotting JointPlots
